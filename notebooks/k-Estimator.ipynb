# %%
from sklearn.cluster import KMeans 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches
import numpy as np
from mpl_toolkits import mplot3d
from fantasyfootball import fantasypros as fp
import matplotlib.style as style
from datetime import date
from fantasyfootball import tiers
from fantasyfootball import config

# %%
# %load_ext autoreload
# %autoreload 2

style.use('ggplot')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# assign league to variable

league = config.justin

# %%
# draftable players dict to assign tiers to "draftable" players

draftable_players = tiers.draftable_position_quantity(league)

# %%
# always have 15 Ks and DSTs
draftable_players
# Out:
# {'DST': 12, 'K': 12, 'RB': 60, 'WR': 60, 'QB': 20, 'TE': 15}

# %%
# kmeans elbow chart

tiers.kmeans_sse_chart(league=config.justin, pos_n=draftable_players)

# %%
tiers.kmeans_sse_chart(league=config.justin, pos_breakout=True, clusters=20)

# %%
# kmeans elbow chart - entire draftable DF by pos

tiers.kmeans_sse_chart(league=config.justin, pos_n=None)

# %%
# kmeans elbow chart - entire draftable DF by pos

tiers.kmeans_sse_chart(league=config.justin, pos_n=35)

# %%
# AIC / BIC chart - full covariance by pos

tiers.gmm_component_silhouette_estimator(league, pos_n=draftable_players, covariance_type='full')

# %%
# AIC / BIC chart - full covariance by pos

tiers.gmm_component_silhouette_estimator(league, pos_n=draftable_players, covariance_type='full')

# %%
# AIC / BIC chart - diag covariance / enitre draftable DF by pos

tiers.gmm_component_silhouette_estimator(league, pos_n=draftable_players, covariance_type='diag')

# %%
# AIC / BIC chart - spherical covariance

tiers.gmm_component_silhouette_estimator(league, pos_n=draftable_players, covariance_type='spherical')

# %%
#top 200 tier estimator
tiers.gmm_component_silhouette_estimator(league, pos_breakout=False, pos_n=None, covariance_type='diag')
