# %%
# %load_ext autoreload
# %autoreload 2
from fantasyfootball import nflfastr

fastr = nflfastr.get_nfl_fast_r_data(2021)

# %%
(nflfastr.team_rec_yards_transform(fastr)
         .pipe(nflfastr.make_team_swarm))

# %%
(nflfastr.team_rec_yards_transform(fastr)
         .pipe(nflfastr.make_team_kde))

# %%
(nflfastr.team_yards_gained_transform(fastr)
         .pipe(nflfastr.make_team_jitter))

# %%
(nflfastr.team_yards_gained_transform(fastr)
         .pipe(nflfastr.make_team_jitter, play_type=True))

# %%
(nflfastr.team_yards_gained_transform(fastr)
         .pipe(nflfastr.make_team_jitter, play_type=True, y_lim_min=10, ylim_max=40))
